# %%
print("Loading Packages...")
import pandas as pd 
# import numpy as np 
import argparse
# import seaborn as sns
# import matplotlib.pyplot as plt
# from sklearn.preprocessing import StandardScaler
# import pyreadr
import os
# Out:
# Loading Packages...

# %%
# sample_sheet = pd.read_csv("/Volumes/Research_Data/Research_Datasets/Sperm/Air_Quality/sample_sheet.csv",header = 0, index_col=0)
# sample_sheet.iloc[:]
# Out:
#                     Sample_Name    Sentrix_ID Sentrix_Position Sample_Well  \
# Sample_ID
# 203010900034_R01C01  02-302-010  2.030110e+11           R01C01         A01
# 203010900034_R02C01  03-097-014  2.030110e+11           R02C01         B01
# 203010900034_R04C01  03-071-032  2.030110e+11           R04C01         D01
# 203010900034_R05C01  03-080-001  2.030110e+11           R05C01         E01
# 203010900034_R06C01  03-071-024  2.030110e+11           R06C01         F01
# ...                         ...           ...              ...         ...
# 203026840080_R03C01     HO98011  2.030270e+11           R03C01         C11
# 203026840080_R04C01     G559003  2.030270e+11           R04C01         D11
# 203026840080_R05C01    11J1-003  2.030270e+11           R05C01         E11
# 203026840080_R06C01     KT1K012  2.030270e+11           R06C01         F11
# 203026840080_R07C01    30PV-011  2.030270e+11           R07C01         G11
#
#                     Sample_Plate Sample_Group  Pool_ID  Comment
# Sample_ID
# 203010900034_R01C01     Plate 01          R_G      NaN      NaN
# 203010900034_R02C01     Plate 01          S_P      NaN      NaN
# 203010900034_R04C01     Plate 01          R_P      NaN      NaN
# 203010900034_R05C01     Plate 01          R_P      NaN      NaN
# 203010900034_R06C01     Plate 01          R_P      NaN      NaN
# ...                          ...          ...      ...      ...
# 203026840080_R03C01     Plate 01          R_G      NaN      NaN
# 203026840080_R04C01     Plate 01          S_G      NaN      NaN
# 203026840080_R05C01     Plate 01          R_G      NaN      NaN
# 203026840080_R06C01     Plate 01          S_P      NaN      NaN
# 203026840080_R07C01     Plate 01          R_P      NaN      NaN
#
# [74 rows x 8 columns]

# %%
# # #  If you need to subset for a specific control sample type you can

# control_subset = []
# for i in sample_sheet.index:
#     if sample_sheet.loc[i,"Sample_Group"] == "S_G":
#         control_subset.append(i)

# print(len(control_subset))
# print(control_subset)


# beta_values = pd.read_csv("/Volumes/Research_Data/Research_Datasets/Sperm/Air_Quality/Air_Quality_beta_values.csv",header = 0,index_col = 0)
# control = beta_values.loc[:,control_subset]
# control.to_csv("/Users/chadpollard/Desktop/Air_Quality_Study/S_G_beta_values.csv")
# control.iloc[:]
# Out:
# 21
# ['203011620056_R05C01', '203011620056_R06C01', '203013220051_R01C01', '203013220051_R02C01', '203013220051_R04C01', '203013220102_R01C01', '203013220102_R02C01', '203013220102_R05C01', '203013220106_R06C01', '203013220106_R07C01', '203017150072_R01C01', '203020780073_R07C01', '203020780073_R08C01', '203026840036_R01C01', '203026840036_R03C01', '203026840044_R01C01', '203026840044_R03C01', '203026840044_R04C01', '203026840044_R05C01', '203026840080_R02C01', '203026840080_R04C01']
#             203011620056_R05C01  203011620056_R06C01  203013220051_R01C01  \
# cg18478105             0.028151             0.028588             0.017121
# cg09835024             0.051456             0.027295             0.030564
# cg14361672             0.162488             0.202161             0.163846
# cg01763666             0.923431             0.925071             0.935721
# cg01763666             0.940491             0.942499             0.949691
# cg12950382             0.866491             0.947508             0.884917
# ...                         ...                  ...                  ...
# cg23079522             0.867271             0.922988             0.972816
# cg16818145             0.073009             0.026260             0.048135
# cg14585103             0.862489             0.913167             0.912463
# cg10633746             0.084846             0.058931             0.071478
# cg12623625             0.777892             0.759900             0.762796
#
# [866091 rows x 21 columns]

# %%
# #  If you need to subset for a specific treatment sample type you can

# treatment_subset = []
# for i in sample_sheet.index:
#     if sample_sheet.loc[i,"Cell_Type"] == "bulk_AD_Temporal Cortex":
#         treatment_subset.append(i)

# print(len(treatment_subset))

# # beta_values = pd.read_csv("/Volumes/Research_Data/Research_Datasets/Blood_Plasma/Prostate_Study_450K/Prostate_Study_450K_beta_values.csv",header = 0,index_col = 0)
# treatment = beta_values.loc[:,treatment_subset]
# treatment.to_csv("/Volumes/Research_Data/USEQ_Analyses/Bulk_Temporal_Cortex_vs_Bulk_AD_Temporal_Cortex/bulk_ad_betas.csv")
# treatment.iloc[:]
# Out:
# 39
#                  GSM2809000_5854945020_R01C01  GSM2809001_5854945020_R02C01  \
# cg00050873                           0.803452                      0.812450
# cg00212031                           0.224546                      0.146422
# cg00213748                           0.643574                      0.640045
# cg00214611                           0.175713                      0.204297
# cg00455876                           0.728289                      0.675564
# ...                                       ...                           ...
# ch.22.909671F                        0.434690                      0.527383
# ch.22.46830341F                      0.365107                      0.430826
# ch.22.1008279F                       0.160545                      0.184386
# ch.22.47579720R                      0.269463                      0.303191
# ch.22.48274842R                      0.294198                      0.240271
#
#                  GSM2809002_5854945020_R03C01  GSM2809003_5854945020_R04C01  \
# cg00050873                           0.819841                      0.568000
# cg00212031                           0.143339                      0.498123
# cg00213748                           0.686261                      0.526267
# cg00214611                           0.192041                      0.498779
# cg00455876                           0.713348                      0.524501
# ...                                       ...                           ...
# ch.22.909671F                        0.472976                      0.450296
# ch.22.46830341F                      0.318466                      0.405195
# ch.22.1008279F                       0.148443                      0.199822
# ch.22.47579720R                      0.286529                      0.310689
# ch.22.48274842R                      0.235073                      0.239562
#
#                  GSM2809004_5854945020_R05C01  GSM2809008_5854945020_R03C02  \
# cg00050873                           0.808593                      0.805260
# cg00212031                           0.192155                      0.148344
# cg00213748                           0.640229                      0.669229
# cg00214611                           0.221074                      0.168605
# cg00455876                           0.758173                      0.670802
# ...                                       ...                           ...
# ch.22.909671F                        0.472942                      0.488346
# ch.22.46830341F                      0.251161                      0.368687
# ch.22.1008279F                       0.180093                      0.172589
# ch.22.47579720R                      0.259042                      0.303887
# ch.22.48274842R                      0.170266                      0.221860
#
#                  GSM2809009_5854945020_R04C02  GSM2809010_5854945020_R05C02  \
# cg00050873                           0.614745                      0.570059
# cg00212031                           0.493963                      0.539190
# cg00213748                           0.575447                      0.577770
# cg00214611                           0.517537                      0.584292
# cg00455876                           0.444697                      0.553947
# ...                                       ...                           ...
# ch.22.909671F                        0.474976                      0.506206
# ch.22.46830341F                      0.305581                      0.458074
# ch.22.1008279F                       0.143400                      0.212510
# ch.22.47579720R                      0.279481                      0.342678
# ch.22.48274842R                      0.213577                      0.252482
# cg00212031                           0.535081
# cg00213748                           0.466605
# cg00214611                           0.517340
# cg00455876                           0.448544
# ...                                       ...
# ch.22.909671F                        0.396214
# ch.22.46830341F                      0.347684
# ch.22.1008279F                       0.177850
# ch.22.47579720R                      0.292930
# ch.22.48274842R                      0.185388
#
# [485512 rows x 39 columns]

# %%
# ann_EPIC = pd.read_csv("/Volumes/Research_Data/My_Github/USEQ-Pipeline/Annotation_Files/450k_annotation.csv",header = 0,index_col = 0,dtype=str)
# ann_EPIC.iloc[:]

# mydf = pd.merge(ann_EPIC,control,left_index=True,right_index=True)
# mydf = pd.merge(mydf,treatment,left_index=True,right_index=True)
# mydf.iloc[:]

# %%
###############
## ARGUMENTS ##
###############
##  Add Arguments from command line
parser=argparse.ArgumentParser(description='Creating .sgr files for USEQ analysis')
parser.add_argument('--base_dir', help='Path to base directory',type=str, required=True)
parser.add_argument('--control_betas', help='Path to control beta values',type=str, required=True)
parser.add_argument('--treatment_betas', help='Path to treatment beta values',type=str, required=True)
parser.add_argument('--illumina_annotation', help='Path to illumina annotation file',type=str, required=True)
parser.add_argument('--USEQ_Prep', help='Path to USEQ Prep Folder',type=str, required=True)

## get arguments
base_dir=args.base_dir
control_betas=args.control_betas
treatment_betas=args.treatment_betas
illumina_annotation=args.illumina_annotation
USEQ_Prep=args.USEQ_Prep

# %%
# Set directory where you want the USEQ_Prep directory and files to be put
path_to_my_dir = base_dir
os.chdir(path_to_my_dir)
print("Home Directory has been set to", path_to_my_dir))
path_to_USEQ_Prep = USEQ_Prep

# Read Control Betas, Treatment Betas, and the desired annotation file (This one is EPIC)
print("Reading in Control Beta Values")
control = pd.read_csv(control_betas,header = 0,index_col = 0)
print("Reading in Treatment Beta Values")
treatment = pd.read_csv(treatment_betas,header = 0,index_col = 0)
print("Reading in Annotation File")
ann_EPIC = pd.read_csv(illumina_annotation,header = 0,index_col = 0)

# Merge Each File
print("Merging Annotation File")
print("Merging Control Betas File")
mydf = pd.merge(ann_EPIC,control,left_index=True,right_index=True)
print("Finished Merging Annotation File")
print("Finished Merging Control Betas File")
print("Merging Treatment Betas File")
mydf = pd.merge(mydf,treatment,left_index=True,right_index=True)
print("Finished Merging Treatment Betas File")
mydf.iloc[:5,:]


chrom = ["chr1","chr2","chr3","chr4","chr5","chr6","chr7","chr8","chr9","chr10","chr11","chr12","chr13","chr14","chr15","chr16","chr17","chr18","chr19","chr20","chr21","chr22","chrX","chrY"]
count = 2
# os.mkdir("/Volumes/Research_Data/USEQ_Analyses/Bulk_vs_Bulk_AD/USEQ_Prep")
for sample in mydf.columns:
    if sample == "CHR" or sample == "START":
        continue
    else:
        os.mkdir(path_to_USEQ_Prep + sample)
        sample_subset = mydf.iloc[:, [0,1,count]]
        count += 1
        for i in chrom:
            c = sample_subset.loc[sample_subset["CHR"] == i,["CHR","START",sample]]
            c.to_csv(path_to_USEQ_Prep + sample + "/" + i + ".sgr", sep = "\t",header=False,index=False)
        print("Finished creating .sgr chromosome files for sample",count-2,"of",len(mydf.columns)-2)
# Out:
# Finished creating .sgr chromosome files for sample 1 of 190
# Finished creating .sgr chromosome files for sample 2 of 190
# Finished creating .sgr chromosome files for sample 3 of 190
# Finished creating .sgr chromosome files for sample 4 of 190
# Finished creating .sgr chromosome files for sample 5 of 190
# Finished creating .sgr chromosome files for sample 6 of 190
# Finished creating .sgr chromosome files for sample 7 of 190
# Finished creating .sgr chromosome files for sample 8 of 190
# Finished creating .sgr chromosome files for sample 9 of 190
# Finished creating .sgr chromosome files for sample 10 of 190
# Finished creating .sgr chromosome files for sample 11 of 190
# Finished creating .sgr chromosome files for sample 12 of 190
# Finished creating .sgr chromosome files for sample 13 of 190
# Finished creating .sgr chromosome files for sample 14 of 190
# Finished creating .sgr chromosome files for sample 15 of 190
# Finished creating .sgr chromosome files for sample 16 of 190
# Finished creating .sgr chromosome files for sample 17 of 190
# Finished creating .sgr chromosome files for sample 18 of 190
# Finished creating .sgr chromosome files for sample 19 of 190
# Finished creating .sgr chromosome files for sample 20 of 190
# Finished creating .sgr chromosome files for sample 21 of 190
# Finished creating .sgr chromosome files for sample 22 of 190
# Finished creating .sgr chromosome files for sample 23 of 190
# Finished creating .sgr chromosome files for sample 24 of 190
# Finished creating .sgr chromosome files for sample 25 of 190
# Finished creating .sgr chromosome files for sample 26 of 190
# Finished creating .sgr chromosome files for sample 27 of 190
# Finished creating .sgr chromosome files for sample 28 of 190
# Finished creating .sgr chromosome files for sample 29 of 190
# Finished creating .sgr chromosome files for sample 30 of 190
# Finished creating .sgr chromosome files for sample 31 of 190
# Finished creating .sgr chromosome files for sample 32 of 190
# Finished creating .sgr chromosome files for sample 33 of 190
# Finished creating .sgr chromosome files for sample 34 of 190
# Finished creating .sgr chromosome files for sample 35 of 190
# Finished creating .sgr chromosome files for sample 36 of 190
# Finished creating .sgr chromosome files for sample 37 of 190
# Finished creating .sgr chromosome files for sample 38 of 190
# Finished creating .sgr chromosome files for sample 39 of 190
# Finished creating .sgr chromosome files for sample 40 of 190
# Finished creating .sgr chromosome files for sample 41 of 190
# Finished creating .sgr chromosome files for sample 42 of 190
# Finished creating .sgr chromosome files for sample 43 of 190
# Finished creating .sgr chromosome files for sample 44 of 190
# Finished creating .sgr chromosome files for sample 45 of 190
# Finished creating .sgr chromosome files for sample 46 of 190
# Finished creating .sgr chromosome files for sample 47 of 190
# Finished creating .sgr chromosome files for sample 48 of 190
# Finished creating .sgr chromosome files for sample 49 of 190
# Finished creating .sgr chromosome files for sample 50 of 190
# Finished creating .sgr chromosome files for sample 51 of 190
# Finished creating .sgr chromosome files for sample 52 of 190
# Finished creating .sgr chromosome files for sample 53 of 190
# Finished creating .sgr chromosome files for sample 54 of 190
# Finished creating .sgr chromosome files for sample 55 of 190
# Finished creating .sgr chromosome files for sample 56 of 190
# Finished creating .sgr chromosome files for sample 57 of 190
# Finished creating .sgr chromosome files for sample 58 of 190
# Finished creating .sgr chromosome files for sample 59 of 190
# Finished creating .sgr chromosome files for sample 60 of 190
# Finished creating .sgr chromosome files for sample 61 of 190
# Finished creating .sgr chromosome files for sample 62 of 190
# Finished creating .sgr chromosome files for sample 63 of 190
# Finished creating .sgr chromosome files for sample 64 of 190
# Finished creating .sgr chromosome files for sample 65 of 190
# Finished creating .sgr chromosome files for sample 66 of 190
# Finished creating .sgr chromosome files for sample 67 of 190
# Finished creating .sgr chromosome files for sample 68 of 190
# Finished creating .sgr chromosome files for sample 69 of 190
# Finished creating .sgr chromosome files for sample 70 of 190
# Finished creating .sgr chromosome files for sample 71 of 190
# Finished creating .sgr chromosome files for sample 72 of 190
# Finished creating .sgr chromosome files for sample 73 of 190
# Finished creating .sgr chromosome files for sample 74 of 190
# Finished creating .sgr chromosome files for sample 75 of 190
# Finished creating .sgr chromosome files for sample 76 of 190
# Finished creating .sgr chromosome files for sample 77 of 190
# Finished creating .sgr chromosome files for sample 78 of 190
# Finished creating .sgr chromosome files for sample 79 of 190
# Finished creating .sgr chromosome files for sample 80 of 190
# Finished creating .sgr chromosome files for sample 81 of 190
# Finished creating .sgr chromosome files for sample 82 of 190
# Finished creating .sgr chromosome files for sample 83 of 190
# Finished creating .sgr chromosome files for sample 84 of 190
# Finished creating .sgr chromosome files for sample 85 of 190
# Finished creating .sgr chromosome files for sample 86 of 190
# Finished creating .sgr chromosome files for sample 87 of 190
# Finished creating .sgr chromosome files for sample 88 of 190
# Finished creating .sgr chromosome files for sample 89 of 190
# Finished creating .sgr chromosome files for sample 90 of 190
# Finished creating .sgr chromosome files for sample 91 of 190
# Finished creating .sgr chromosome files for sample 92 of 190
# Finished creating .sgr chromosome files for sample 93 of 190
# Finished creating .sgr chromosome files for sample 94 of 190
# Finished creating .sgr chromosome files for sample 95 of 190
# Finished creating .sgr chromosome files for sample 96 of 190
# Finished creating .sgr chromosome files for sample 97 of 190
# Finished creating .sgr chromosome files for sample 98 of 190
# Finished creating .sgr chromosome files for sample 99 of 190
# Finished creating .sgr chromosome files for sample 100 of 190
# Finished creating .sgr chromosome files for sample 101 of 190
# Finished creating .sgr chromosome files for sample 102 of 190
# Finished creating .sgr chromosome files for sample 103 of 190
# Finished creating .sgr chromosome files for sample 104 of 190
# Finished creating .sgr chromosome files for sample 105 of 190
# Finished creating .sgr chromosome files for sample 106 of 190
# Finished creating .sgr chromosome files for sample 107 of 190
# Finished creating .sgr chromosome files for sample 108 of 190
# Finished creating .sgr chromosome files for sample 109 of 190
# Finished creating .sgr chromosome files for sample 110 of 190
# Finished creating .sgr chromosome files for sample 111 of 190
# Finished creating .sgr chromosome files for sample 112 of 190
# Finished creating .sgr chromosome files for sample 113 of 190
# Finished creating .sgr chromosome files for sample 114 of 190
# Finished creating .sgr chromosome files for sample 115 of 190
# Finished creating .sgr chromosome files for sample 116 of 190
# Finished creating .sgr chromosome files for sample 117 of 190
# Finished creating .sgr chromosome files for sample 118 of 190
# Finished creating .sgr chromosome files for sample 119 of 190
# Finished creating .sgr chromosome files for sample 120 of 190
# Finished creating .sgr chromosome files for sample 121 of 190
# Finished creating .sgr chromosome files for sample 122 of 190
# Finished creating .sgr chromosome files for sample 123 of 190
# Finished creating .sgr chromosome files for sample 124 of 190
# Finished creating .sgr chromosome files for sample 125 of 190
# Finished creating .sgr chromosome files for sample 126 of 190
# Finished creating .sgr chromosome files for sample 127 of 190
# Finished creating .sgr chromosome files for sample 128 of 190
# Finished creating .sgr chromosome files for sample 129 of 190
# Finished creating .sgr chromosome files for sample 130 of 190
# Finished creating .sgr chromosome files for sample 131 of 190
# Finished creating .sgr chromosome files for sample 132 of 190
# Finished creating .sgr chromosome files for sample 133 of 190
# Finished creating .sgr chromosome files for sample 134 of 190
# Finished creating .sgr chromosome files for sample 135 of 190
# Finished creating .sgr chromosome files for sample 136 of 190
# Finished creating .sgr chromosome files for sample 137 of 190
# Finished creating .sgr chromosome files for sample 138 of 190
# Finished creating .sgr chromosome files for sample 139 of 190
# Finished creating .sgr chromosome files for sample 140 of 190
# Finished creating .sgr chromosome files for sample 141 of 190
# Finished creating .sgr chromosome files for sample 142 of 190
# Finished creating .sgr chromosome files for sample 143 of 190
# Finished creating .sgr chromosome files for sample 144 of 190
# Finished creating .sgr chromosome files for sample 145 of 190
# Finished creating .sgr chromosome files for sample 146 of 190
# Finished creating .sgr chromosome files for sample 147 of 190
# Finished creating .sgr chromosome files for sample 148 of 190
# Finished creating .sgr chromosome files for sample 149 of 190
# Finished creating .sgr chromosome files for sample 150 of 190
# Finished creating .sgr chromosome files for sample 151 of 190
# Finished creating .sgr chromosome files for sample 152 of 190
# Finished creating .sgr chromosome files for sample 153 of 190
# Finished creating .sgr chromosome files for sample 154 of 190
# Finished creating .sgr chromosome files for sample 155 of 190
# Finished creating .sgr chromosome files for sample 156 of 190
# Finished creating .sgr chromosome files for sample 157 of 190
# Finished creating .sgr chromosome files for sample 158 of 190
# Finished creating .sgr chromosome files for sample 159 of 190
# Finished creating .sgr chromosome files for sample 160 of 190
# Finished creating .sgr chromosome files for sample 161 of 190
# Finished creating .sgr chromosome files for sample 162 of 190
# Finished creating .sgr chromosome files for sample 163 of 190
# Finished creating .sgr chromosome files for sample 164 of 190
# Finished creating .sgr chromosome files for sample 165 of 190
# Finished creating .sgr chromosome files for sample 166 of 190
# Finished creating .sgr chromosome files for sample 167 of 190
# Finished creating .sgr chromosome files for sample 168 of 190
# Finished creating .sgr chromosome files for sample 169 of 190
# Finished creating .sgr chromosome files for sample 170 of 190
# Finished creating .sgr chromosome files for sample 171 of 190
# Finished creating .sgr chromosome files for sample 172 of 190
# Finished creating .sgr chromosome files for sample 173 of 190
# Finished creating .sgr chromosome files for sample 174 of 190
# Finished creating .sgr chromosome files for sample 175 of 190
# Finished creating .sgr chromosome files for sample 176 of 190
# Finished creating .sgr chromosome files for sample 177 of 190
# Finished creating .sgr chromosome files for sample 178 of 190
# Finished creating .sgr chromosome files for sample 179 of 190
# Finished creating .sgr chromosome files for sample 180 of 190
# Finished creating .sgr chromosome files for sample 181 of 190
# Finished creating .sgr chromosome files for sample 182 of 190
# Finished creating .sgr chromosome files for sample 183 of 190
# Finished creating .sgr chromosome files for sample 184 of 190
# Finished creating .sgr chromosome files for sample 185 of 190
# Finished creating .sgr chromosome files for sample 186 of 190
# Finished creating .sgr chromosome files for sample 187 of 190
# Finished creating .sgr chromosome files for sample 188 of 190
# Finished creating .sgr chromosome files for sample 189 of 190
# Finished creating .sgr chromosome files for sample 190 of 190
